# %%
import turtle

# Create a turtle object
pen = turtle.Turtle()

# Set the speed of drawing
pen.speed(1)

# Draw a square
for i in range(4):
    pen.forward(100)  # Move forward by 100 units
    pen.right(90)     # Turn right by 90 degrees

# Keep the window open until it is closed manually
turtle.done()

# %%
import turtle

def render_koch_snowflake(size: int = 300, depth: int = 4, speed: int = 0) -> None:
    """
    Render a Koch snowflake fractal using turtle graphics.

    Parameters
    ----------
    size : int
        The length of each side of the outer triangle.
    depth : int
        The recursion depth; higher values yield more detail.
    speed : int
        Turtle drawing speed (0 is fastest, 1..10 are slower).
    """

    def koch_segment(pen: turtle.Turtle, length: float, n: int) -> None:
        if n == 0:
            pen.forward(length)
            return
        length /= 3.0
        koch_segment(pen, length, n - 1)
        pen.left(50)
        koch_segment(pen, length, n - 1)
        pen.right(120)
        koch_segment(pen, length, n - 1)
        pen.left(60)
        koch_segment(pen, length, n - 1)

    # Setup
    screen = turtle.Screen()
    screen.title("Koch Snowflake")
    pen = turtle.Turtle()
    pen.hideturtle()
    pen.speed(speed)
    pen.penup()

    # Position the turtle so the snowflake is centered
    pen.goto(-size / 2, size / 3)
    pen.pendown()

    # Draw the three sides of the snowflake
    for _ in range(3):
        koch_segment(pen, size, depth)
        pen.right(120)

    turtle.done()


# Example usage:
if __name__ == "__main__":
    render_koch_snowflake(size=300, depth=4, speed=0)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[4], line 52
#      50 # Example usage:
#      51 if __name__ == "__main__":
# ---> 52     render_koch_snowflake(size=300, depth=4, speed=0)
#
# Cell In[4], line 33, in render_koch_snowflake(size, depth, speed)
#      31 screen = turtle.Screen()
#      32 screen.title("Koch Snowflake")
# ---> 33 pen = turtle.Turtle()
#      34 pen.hideturtle()
#      35 pen.speed(speed)
#
# File /usr/lib/python3.12/turtle.py:3876, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3874 if Turtle._screen is None:
#    3875     Turtle._screen = Screen()
# -> 3876 RawTurtle.__init__(self, Turtle._screen,
#    3877                    shape=shape,
#    3878                    undobuffersize=undobuffersize,
#    3879                    visible=visible)
#
# File /usr/lib/python3.12/turtle.py:2565, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2563 self._undobuffersize = undobuffersize
#    2564 self.undobuffer = Tbuffer(undobuffersize)
# -> 2565 self._update()
#
# File /usr/lib/python3.12/turtle.py:2668, in RawTurtle._update(self)
#    2666     return
#    2667 elif screen._tracing == 1:
# -> 2668     self._update_data()
#    2669     self._drawturtle()
#    2670     screen._update()                  # TurtleScreenBase
#
# File /usr/lib/python3.12/turtle.py:2654, in RawTurtle._update_data(self)
#    2653 def _update_data(self):
# -> 2654     self.screen._incrementudc()
#    2655     if self.screen._updatecounter != 0:
#    2656         return
#
# File /usr/lib/python3.12/turtle.py:1284, in TurtleScreen._incrementudc(self)
#    1282 if not TurtleScreen._RUNNING:
#    1283     TurtleScreen._RUNNING = True
# -> 1284     raise Terminator
#    1285 if self._tracing > 0:
#    1286     self._updatecounter += 1
#
# Terminator:

# %%
import turtle
from typing import Dict, List, Callable, Tuple, Optional

def generate_lsystem(axiom: str, rules: Dict[str, str], iterations: int) -> List[str]:
    s = axiom
    for _ in range(iterations):
        s = "".join(rules.get(ch, ch) for ch in s)
    return list(s)

def render_lsystem(
    seq: List[str],
    angle: float,
    step: float,
    *,
    start_pos: Tuple[float, float] = (0.0, 0.0),
    heading: float = 0.0,
    speed: int = 0,
    custom_actions: Optional[Dict[str, Callable[[turtle.Turtle, float, float, list], None]]] = None,
    window_title: str = "L-System"
) -> None:
    screen = turtle.Screen()
    screen.title(window_title)
    pen = turtle.Turtle(visible=False)
    pen.speed(speed)
    pen.penup()
    pen.setheading(heading)
    pen.goto(*start_pos)
    pen.pendown()

    stack: list = []

    def act_forward(p: turtle.Turtle, a: float, st: float, _stack: list):
        p.forward(st)

    def act_move(p: turtle.Turtle, a: float, st: float, _stack: list):
        p.penup(); p.forward(st); p.pendown()

    def act_left(p: turtle.Turtle, a: float, st: float, _stack: list):
        p.left(a)

    def act_right(p: turtle.Turtle, a: float, st: float, _stack: list):
        p.right(a)

    def act_push(p: turtle.Turtle, a: float, st: float, _stack: list):
        _stack.append((p.position(), p.heading()))

    def act_pop(p: turtle.Turtle, a: float, st: float, _stack: list):
        if _stack:
            pos, hd = _stack.pop()
            p.penup(); p.goto(pos); p.setheading(hd); p.pendown()

    default_actions: Dict[str, Callable[[turtle.Turtle, float, float, list], None]] = {
        "F": act_forward,
        "G": act_forward,
        "f": act_move,
        "+": act_left,
        "-": act_right,
        "[": act_push,
        "]": act_pop,
    }

    if custom_actions:
        default_actions.update(custom_actions)

    for ch in seq:
        action = default_actions.get(ch)
        if action:
            action(pen, angle, step, stack)

    turtle.done()

# %%
# seq = generate_lsystem("F", {"F": "F+F--F+F"}, iterations=3)
# render_lsystem(seq, angle=59, step=5, start_pos=(-300, 0), heading=0, speed=0, window_title="Koch Curve")

seq = generate_lsystem("X", {"X": "F-[[X]+X]+F[+FX]-X", "F": "FF"}, iterations=5)
render_lsystem(seq, angle=24, step=5, start_pos=(0, -300), heading=90, speed=0, window_title="Plant")

# 2) Custom draw rule example (e.g., dot on 'F'):
# custom = {"F": lambda p, a, st, stk: (p.dot(2), p.forward(st))}
# seq = generate_lsystem("F+F+F+F", {"F": "F+F-F-F+F"}, iterations=1)  # Von Koch-like square variant
# render_lsystem(seq, angle=89, step=5, custom_actions=custom, start_pos=(-200, -200), speed=0, window_title="Custom Actions")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[2], line 5
#       1 # seq = generate_lsystem("F", {"F": "F+F--F+F"}, iterations=3)
#       2 # render_lsystem(seq, angle=59, step=5, start_pos=(-300, 0), heading=0, speed=0, window_title="Koch Curve")
#       4 seq = generate_lsystem("X", {"X": "F-[[X]+X]+F[+FX]-X", "F": "FF"}, iterations=10)
# ----> 5 render_lsystem(seq, angle=24, step=5, start_pos=(0, -300), heading=90, speed=0, window_title="Plant")
#       7 # 2) Custom draw rule example (e.g., dot on 'F'):
#       8 # custom = {"F": lambda p, a, st, stk: (p.dot(2), p.forward(st))}
#       9 # seq = generate_lsystem("F+F+F+F", {"F": "F+F-F-F+F"}, iterations=1)  # Von Koch-like square variant
#      10 # render_lsystem(seq, angle=89, step=5, custom_actions=custom, start_pos=(-200, -200), speed=0, window_title="Custom Actions")
#
# Cell In[1], line 68, in render_lsystem(seq, angle, step, start_pos, heading, speed, custom_actions, window_title)
#      66     action = default_actions.get(ch)
#      67     if action:
# ---> 68         action(pen, angle, step, stack)
#      70 turtle.done()
#
# Cell In[1], line 33, in render_lsystem.<locals>.act_forward(p, a, st, _stack)
#      32 def act_forward(p: turtle.Turtle, a: float, st: float, _stack: list):
# ---> 33     p.forward(st)
#
# File /usr/lib/python3.12/turtle.py:1636, in TNavigator.forward(self, distance)
#    1615 def forward(self, distance):
#    1616     """Move the turtle forward by the specified distance.
#    1617
#    1618     Aliases: forward | fd
#    (...)   1634     (-50.00,0.00)
#    1635     """
# -> 1636     self._go(distance)
#
# File /usr/lib/python3.12/turtle.py:1597, in TNavigator._go(self, distance)
#    1595 """move turtle forward by specified distance"""
#    1596 ende = self._position + self._orient * distance
# -> 1597 self._goto(ende)
#
# File /usr/lib/python3.12/turtle.py:3230, in RawTurtle._goto(self, end)
#    3222 go_modes = ( self._drawing,
#    3223              self._pencolor,
#    3224              self._pensize,
#    3225              isinstance(self._fillpath, list))
#    3226 screen = self.screen
#    3227 undo_entry = ("go", self._position, end, go_modes,
#    3228               (self.currentLineItem,
#    3229               self.currentLine[:],
# -> 3230               screen._pointlist(self.currentLineItem),
#    3231               self.items[:])
#    3232               )
#    3233 if self.undobuffer:
#    3234     self.undobuffer.push(undo_entry)
#
# File /usr/lib/python3.12/turtle.py:745, in TurtleScreenBase._pointlist(self, item)
#     737 def _pointlist(self, item):
#     738     """returns list of coordinate-pairs of points of item
#     739     Example (for insiders):
#     740     >>> from turtle import *
#    (...)    743     (9.9999999999999982, 0.0)]
#     744     >>> """
# --> 745     cl = self.cv.coords(item)
#     746     pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     747     return  pl
#
# File <string>:1, in coords(self, *args, **kw)
#
# File /usr/lib/python3.12/tkinter/__init__.py:2840, in Canvas.coords(self, *args)
#    2836 """Return a list of coordinates for the item given in ARGS."""
#    2837 args = _flatten(args)
#    2838 return [self.tk.getdouble(x) for x in
#    2839                    self.tk.splitlist(
# -> 2840            self.tk.call((self._w, 'coords') + args))]
#
# TclError: invalid command name ".!canvas"
